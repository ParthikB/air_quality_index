# %%
from tqdm import tqdm_gui as tqdm

# %%
import time

# %%
for i in tqdm(range(11)):
    for j in tqdm(range(10), leave=True):
        pass
# Out:
# /home/atom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: TqdmExperimentalWarning: GUI is experimental/alpha
#   """Entry point for launching an IPython kernel.
# /home/atom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmExperimentalWarning: GUI is experimental/alpha
#
# /home/atom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmExperimentalWarning: GUI is experimental/alpha
#
# /home/atom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmExperimentalWarning: GUI is experimental/alpha
#
# /home/atom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmExperimentalWarning: GUI is experimental/alpha
#
# /home/atom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmExperimentalWarning: GUI is experimental/alpha
#
# /home/atom/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmExperimentalWarning: GUI is experimental/alpha
#
# ...
